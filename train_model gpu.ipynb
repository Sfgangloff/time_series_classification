# %% [markdown]
# # Imports

# %% [markdown]
# Todo: reduce batches for training with model number 2.
# Check how to solve memory problems with tensorflow-directml
# Add feature engineering.
# Add normalization.

# %%
from load_df import load_df

# %%
dfx = load_df("data/train/x_train.csv")
dfy = load_df("data/train/y_train.csv")

# %%
print(dfx["obs_id"].unique())
print(dfy["obs_id"].unique())
# Out:
# [     0      1      2 ... 160797 160798 160799]

# %% [markdown]
# # Modules instanciation

# %%
CATEGORY_COLUMNS = ["venue","action","trade","side"]
SCALAR_COLUMNS = ["price","bid","ask","bid_size","ask_size","flux"]
INDEX_COLUMN= "obs_id"

# %%
from encoder import Encoder
encoder = Encoder(category_colums=CATEGORY_COLUMNS)
dfx = encoder.apply(dfx)
CATEGORY_COLUMNS = encoder.new_columns
# Out:
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
TEST_SIZE = 1000
from feature_engineer import FeatureEngineer
feature_engineer = FeatureEngineer(category_columns=CATEGORY_COLUMNS,
                                   scalar_columns=SCALAR_COLUMNS,
                                   index_column=INDEX_COLUMN)
from preparator import Preparator
preparator = Preparator()

# %%
df_x = feature_engineer.apply(dfx)
# Out:
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)

# %%
trainx_array = preparator.input_df_to_array(df=df_x,
                index_column=INDEX_COLUMN)
trainy_array = preparator.output_df_to_array(df=dfy)
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 trainx_array = preparator.input_df_to_array(df=df_x,
#       2                 index_column=INDEX_COLUMN)
#       3 trainy_array = preparator.output_df_to_array(df=dfy)
#
# File d:\challenge CFM\challenge CFM\preparator.py:13, in Preparator.input_df_to_array(self, df, index_column)
#       9 def input_df_to_array(self,df:pd.DataFrame,
#      10                       index_column:str):
#      12     grouped = df.groupby(index_column)
# ---> 13     group_arrays = [group.values[:, 1:] for _, group in grouped]
#      14     max_rows = max(group.shape[0] for group in group_arrays)
#      15     max_cols = max(group.shape[1] for group in group_arrays)
#
# File d:\challenge CFM\challenge CFM\preparator.py:13, in <listcomp>(.0)
#       9 def input_df_to_array(self,df:pd.DataFrame,
#      10                       index_column:str):
#      12     grouped = df.groupby(index_column)
# ---> 13     group_arrays = [group.values[:, 1:] for _, group in grouped]
#      14     max_rows = max(group.shape[0] for group in group_arrays)
#      15     max_cols = max(group.shape[1] for group in group_arrays)
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\groupby\ops.py:620, in BaseGrouper.get_iterator(self, data, axis)
#     618 splitter = self._get_splitter(data, axis=axis)
#     619 keys = self.group_keys_seq
# --> 620 yield from zip(keys, splitter)
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\groupby\ops.py:1150, in DataSplitter.__iter__(self)
#    1149 def __iter__(self) -> Iterator:
# -> 1150     sdata = self._sorted_data
#    1152     if self.ngroups == 0:
#    1153         # we are inside a generator, rather than raise StopIteration
#    1154         # we merely return signal the end
#    1155         return
#
# File properties.pyx:36, in pandas._libs.properties.CachedProperty.__get__()
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\groupby\ops.py:1164, in DataSplitter._sorted_data(self)
#    1162 @cache_readonly
#    1163 def _sorted_data(self) -> NDFrameT:
# -> 1164     return self.data.take(self._sort_idx, axis=self.axis)
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\generic.py:4130, in NDFrame.take(self, indices, axis, **kwargs)
#    4125     # We can get here with a slice via DataFrame.__getitem__
#    4126     indices = np.arange(
#    4127         indices.start, indices.stop, indices.step, dtype=np.intp
#    4128     )
# -> 4130 new_data = self._mgr.take(
#    4131     indices,
#    4132     axis=self._get_block_manager_axis(axis),
#    4133     verify=True,
#    4134 )
#    4135 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4136     self, method="take"
#    4137 )
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\internals\managers.py:894, in BaseBlockManager.take(self, indexer, axis, verify)
#     891 indexer = maybe_convert_indices(indexer, n, verify=verify)
#     893 new_labels = self.axes[axis].take(indexer)
# --> 894 return self.reindex_indexer(
#     895     new_axis=new_labels,
#     896     indexer=indexer,
#     897     axis=axis,
#     898     allow_dups=True,
#     899     copy=None,
#     900 )
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\internals\managers.py:687, in BaseBlockManager.reindex_indexer(self, new_axis, indexer, axis, fill_value, allow_dups, copy, only_slice, use_na_proxy)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
# --> 687     new_blocks = [
#     688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\internals\managers.py:688, in <listcomp>(.0)
#     680     new_blocks = self._slice_take_blocks_ax0(
#     681         indexer,
#     682         fill_value=fill_value,
#     683         only_slice=only_slice,
#     684         use_na_proxy=use_na_proxy,
#     685     )
#     686 else:
#     687     new_blocks = [
# --> 688         blk.take_nd(
#     689             indexer,
#     690             axis=1,
#     691             fill_value=(
#     692                 fill_value if fill_value is not None else blk.fill_value
#     693             ),
#     694         )
#     695         for blk in self.blocks
#     696     ]
#     698 new_axes = list(self.axes)
#     699 new_axes[axis] = new_axis
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\internals\blocks.py:1307, in Block.take_nd(self, indexer, axis, new_mgr_locs, fill_value)
#    1304     allow_fill = True
#    1306 # Note: algos.take_nd has upcast logic similar to coerce_to_target_dtype
# -> 1307 new_values = algos.take_nd(
#    1308     values, indexer, axis=axis, allow_fill=allow_fill, fill_value=fill_value
#    1309 )
#    1311 # Called from three places in managers, all of which satisfy
#    1312 #  these assertions
#    1313 if isinstance(self, ExtensionBlock):
#    1314     # NB: in this case, the 'axis' kwarg will be ignored in the
#    1315     #  algos.take_nd call above.
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\array_algos\take.py:117, in take_nd(arr, indexer, axis, fill_value, allow_fill)
#     114     return arr.take(indexer, fill_value=fill_value, allow_fill=allow_fill)
#     116 arr = np.asarray(arr)
# --> 117 return _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#
# File d:\challenge CFM\challenge CFM\.venv\lib\site-packages\pandas\core\array_algos\take.py:157, in _take_nd_ndarray(arr, indexer, axis, fill_value, allow_fill)
#     155     out = np.empty(out_shape, dtype=dtype, order="F")
#     156 else:
# --> 157     out = np.empty(out_shape, dtype=dtype)
#     159 func = _get_take_nd_function(
#     160     arr.ndim, arr.dtype, out.dtype, axis=axis, mask_info=mask_info
#     161 )
#     162 func(arr, indexer, out, fill_value)
#
# MemoryError: Unable to allocate 123. MiB for an array with shape (16080000, 1) and data type int64

# %%
N_TIMESTEPS, N_FEATURES, N_OUTPUTS = trainx_array.shape[1], trainx_array.shape[2], trainy_array.shape[1]
from model import create_model
model = create_model(n_timesteps=N_TIMESTEPS,
                     n_features=N_FEATURES,
                     n_outputs=N_OUTPUTS,
                     model_type=0)

# %% [markdown]
# # Training

# %%
VERBOSE, EPOCHS, BATCH_SIZE = 0, 50, 1000
model.fit(trainx_array,
            trainy_array,
            epochs=EPOCHS,
            batch_size=BATCH_SIZE,
            verbose=VERBOSE)
# Out:
# 0
# d:\challenge CFM\challenge CFM\feature_engineer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)] = df.groupby(self.index_column)[column].shift(1)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff'.format(column)] = df[column] - df['{}_lag1'.format(column)]
# d:\challenge CFM\challenge CFM\feature_engineer.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)]=df['{}'.format(column)].rolling(window=3).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)]=df['{}'.format(column)].rolling(window=6).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)]=df['{}'.format(column)].rolling(window=9).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_mean'.format(column)] = df.groupby(self.index_column)[column].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff_mean'.format(column)] = df.groupby(self.index_column)[s_diff].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_med'.format(column)] = df.groupby(self.index_column)[column].transform('median')
# d:\challenge CFM\challenge CFM\feature_engineer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_std'.format(column)] = df.groupby(self.index_column)[column].transform('std')
# d:\challenge CFM\challenge CFM\feature_engineer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_skew'.format(column)] = df.groupby(self.index_column)[column].transform('skew')
# d:\challenge CFM\challenge CFM\feature_engineer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_min'.format(column)] = df.groupby(self.index_column)[column].transform('min')
# d:\challenge CFM\challenge CFM\feature_engineer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_max'.format(column)] = df.groupby(self.index_column)[column].transform('max')
# d:\challenge CFM\challenge CFM\feature_engineer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)] = df.groupby(self.index_column)[column].shift(1)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff'.format(column)] = df[column] - df['{}_lag1'.format(column)]
# d:\challenge CFM\challenge CFM\feature_engineer.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)]=df['{}'.format(column)].rolling(window=3).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)]=df['{}'.format(column)].rolling(window=6).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)]=df['{}'.format(column)].rolling(window=9).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_mean'.format(column)] = df.groupby(self.index_column)[column].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff_mean'.format(column)] = df.groupby(self.index_column)[s_diff].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_med'.format(column)] = df.groupby(self.index_column)[column].transform('median')
# d:\challenge CFM\challenge CFM\feature_engineer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_std'.format(column)] = df.groupby(self.index_column)[column].transform('std')
# d:\challenge CFM\challenge CFM\feature_engineer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_skew'.format(column)] = df.groupby(self.index_column)[column].transform('skew')
# d:\challenge CFM\challenge CFM\feature_engineer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_min'.format(column)] = df.groupby(self.index_column)[column].transform('min')
# d:\challenge CFM\challenge CFM\feature_engineer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_max'.format(column)] = df.groupby(self.index_column)[column].transform('max')
# d:\challenge CFM\challenge CFM\feature_engineer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)] = df.groupby(self.index_column)[column].shift(1)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff'.format(column)] = df[column] - df['{}_lag1'.format(column)]
# d:\challenge CFM\challenge CFM\feature_engineer.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)]=df['{}'.format(column)].rolling(window=3).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)]=df['{}'.format(column)].rolling(window=6).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)]=df['{}'.format(column)].rolling(window=9).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_mean'.format(column)] = df.groupby(self.index_column)[column].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff_mean'.format(column)] = df.groupby(self.index_column)[s_diff].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_med'.format(column)] = df.groupby(self.index_column)[column].transform('median')
# d:\challenge CFM\challenge CFM\feature_engineer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_std'.format(column)] = df.groupby(self.index_column)[column].transform('std')
# d:\challenge CFM\challenge CFM\feature_engineer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_skew'.format(column)] = df.groupby(self.index_column)[column].transform('skew')
# d:\challenge CFM\challenge CFM\feature_engineer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_min'.format(column)] = df.groupby(self.index_column)[column].transform('min')
# d:\challenge CFM\challenge CFM\feature_engineer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_max'.format(column)] = df.groupby(self.index_column)[column].transform('max')
# d:\challenge CFM\challenge CFM\feature_engineer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)] = df.groupby(self.index_column)[column].shift(1)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff'.format(column)] = df[column] - df['{}_lag1'.format(column)]
# d:\challenge CFM\challenge CFM\feature_engineer.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)]=df['{}'.format(column)].rolling(window=3).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)]=df['{}'.format(column)].rolling(window=6).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)]=df['{}'.format(column)].rolling(window=9).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_mean'.format(column)] = df.groupby(self.index_column)[column].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff_mean'.format(column)] = df.groupby(self.index_column)[s_diff].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_med'.format(column)] = df.groupby(self.index_column)[column].transform('median')
# d:\challenge CFM\challenge CFM\feature_engineer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_std'.format(column)] = df.groupby(self.index_column)[column].transform('std')
# d:\challenge CFM\challenge CFM\feature_engineer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_skew'.format(column)] = df.groupby(self.index_column)[column].transform('skew')
# d:\challenge CFM\challenge CFM\feature_engineer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_min'.format(column)] = df.groupby(self.index_column)[column].transform('min')
# d:\challenge CFM\challenge CFM\feature_engineer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_max'.format(column)] = df.groupby(self.index_column)[column].transform('max')
# d:\challenge CFM\challenge CFM\feature_engineer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)] = df.groupby(self.index_column)[column].shift(1)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff'.format(column)] = df[column] - df['{}_lag1'.format(column)]
# d:\challenge CFM\challenge CFM\feature_engineer.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)]=df['{}'.format(column)].rolling(window=3).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)]=df['{}'.format(column)].rolling(window=6).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)]=df['{}'.format(column)].rolling(window=9).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_mean'.format(column)] = df.groupby(self.index_column)[column].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff_mean'.format(column)] = df.groupby(self.index_column)[s_diff].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_med'.format(column)] = df.groupby(self.index_column)[column].transform('median')
# d:\challenge CFM\challenge CFM\feature_engineer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_std'.format(column)] = df.groupby(self.index_column)[column].transform('std')
# d:\challenge CFM\challenge CFM\feature_engineer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_skew'.format(column)] = df.groupby(self.index_column)[column].transform('skew')
# d:\challenge CFM\challenge CFM\feature_engineer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_min'.format(column)] = df.groupby(self.index_column)[column].transform('min')
# d:\challenge CFM\challenge CFM\feature_engineer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_max'.format(column)] = df.groupby(self.index_column)[column].transform('max')
# d:\challenge CFM\challenge CFM\feature_engineer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)] = df.groupby(self.index_column)[column].shift(1)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...
# d:\challenge CFM\challenge CFM\feature_engineer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)]=df['{}'.format(column)].rolling(window=9).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_mean'.format(column)] = df.groupby(self.index_column)[column].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff_mean'.format(column)] = df.groupby(self.index_column)[s_diff].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_med'.format(column)] = df.groupby(self.index_column)[column].transform('median')
# d:\challenge CFM\challenge CFM\feature_engineer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_std'.format(column)] = df.groupby(self.index_column)[column].transform('std')
# d:\challenge CFM\challenge CFM\feature_engineer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_skew'.format(column)] = df.groupby(self.index_column)[column].transform('skew')
# d:\challenge CFM\challenge CFM\feature_engineer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_min'.format(column)] = df.groupby(self.index_column)[column].transform('min')
# d:\challenge CFM\challenge CFM\feature_engineer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_max'.format(column)] = df.groupby(self.index_column)[column].transform('max')
# d:\challenge CFM\challenge CFM\feature_engineer.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)] = df.groupby(self.index_column)[column].shift(1)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_lag1'.format(column)].fillna(df[column].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff'.format(column)] = df[column] - df['{}_lag1'.format(column)]
# d:\challenge CFM\challenge CFM\feature_engineer.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)]=df['{}'.format(column)].rolling(window=3).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)]=df['{}'.format(column)].rolling(window=6).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)]=df['{}'.format(column)].rolling(window=9).mean()
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean3'.format(column)].fillna(df['{}_roll_mean3'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean6'.format(column)].fillna(df['{}_roll_mean6'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_roll_mean9'.format(column)].fillna(df['{}_roll_mean9'.format(column)].median(), inplace=True)
# d:\challenge CFM\challenge CFM\feature_engineer.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_mean'.format(column)] = df.groupby(self.index_column)[column].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:27: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_diff_mean'.format(column)] = df.groupby(self.index_column)[s_diff].transform('mean')
# d:\challenge CFM\challenge CFM\feature_engineer.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_med'.format(column)] = df.groupby(self.index_column)[column].transform('median')
# d:\challenge CFM\challenge CFM\feature_engineer.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_std'.format(column)] = df.groupby(self.index_column)[column].transform('std')
# d:\challenge CFM\challenge CFM\feature_engineer.py:30: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_skew'.format(column)] = df.groupby(self.index_column)[column].transform('skew')
# d:\challenge CFM\challenge CFM\feature_engineer.py:32: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_min'.format(column)] = df.groupby(self.index_column)[column].transform('min')
# d:\challenge CFM\challenge CFM\feature_engineer.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['{}_max'.format(column)] = df.groupby(self.index_column)[column].transform('max')
# 1

# %%
model.save("pretrained_gpu_benchmark.keras")

# %% [markdown]
# # Prediction

# %%
# testx_df = splitter_x.get_test_df()
import pandas as pd
testx_df = pd.read_csv("data/test/x_test.csv")
testx_df = feature_engineer.apply(testx_df)
# testy_df = splitter_y.get_test_df()

# %%
testx_array = preparator.input_df_to_array(testx_df,index_column=INDEX_COLUMN)
# testy_array = preparator.output_df_to_array(testy_df)

# %%
prediction = model.predict(testx_array)
# _, accuracy = model.evaluate(testx_array, testy_array, batch_size=BATCH_SIZE, verbose=0)

# %%
# print(accuracy)

# %%
# output = [max(enumerate(row), key=lambda x: x[1])[0] for row in prediction]
#import pandas as pd
#output_df = pd.DataFrame({"obs_id":list(df_test["obs_id"].unique()),"eq_code_cat":output})
#output_df.to_csv("data/submission_benchmark.csv",index=False)
